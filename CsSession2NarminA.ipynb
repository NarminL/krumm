# %% [markdown]
# ## It contains only models which had a new release every year between 1999 and 2008 - this was used as a proxy for the popularity of the car.

# %% [markdown]
# ### 1.Import packages

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 2.Import dataset of cars(also show top 5 colums,shape and columns name)

# %%
cars=pd.read_excel(r'C:\Users\Sevinc\Desktop\cars.xlsx')
cars
# Out:
#     manufacturer   model  displ  year  cyl       trans drv   cty   hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p
# 3           audi      a4    2.0  2008    4    auto(av)   f  21.0  30.0  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p
# ..           ...     ...    ...   ...  ...         ...  ..   ...   ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f  19.0  28.0  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f  21.0  29.0  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f  16.0  26.0  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f  18.0  26.0  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f  17.0  26.0  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# 229  midsize
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
#
# [234 rows x 11 columns]

# %%
cars.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %%
cars.shape
# Out:
# (234, 11)

# %%
for col in cars.columns:
    print(col)
#ve ya
list(cars.columns)
# Out:
# manufacturer
# model
# displ
# year
# cyl
# trans
# drv
# cty
# hwy
# fl
# class
# ['manufacturer',
#  'model',
#  'displ',
#  'year',
#  'cyl',
#  'trans',
#  'drv',
#  'cty',
#  'hwy',
#  'fl',
#  'class']

# %% [markdown]
# ### 3. Find correlation between variables.

# %%
df=pd.DataFrame(cars)
df.corr()
# Out:
#           displ      year       cyl       cty       hwy
# displ  1.000000  0.128547  0.931744 -0.812594 -0.769741
# year   0.128547  1.000000  0.122245 -0.039814 -0.014702
# cyl    0.931744  0.122245  1.000000 -0.804726 -0.763860
# cty   -0.812594 -0.039814 -0.804726  1.000000  0.957549
# hwy   -0.769741 -0.014702 -0.763860  0.957549  1.000000

# %% [markdown]
# ### 4. Display relationship between highway miles per gallon and city miles per gallon
# * Use scatter in matplotlib
# * how variables correlated according to scatter

# %%
import matplotlib.pyplot as plt
plt.scatter(df['hwy'],df['cty'])
plt.title("Point observations")
plt.xlabel("highway miles per gallon")
plt.ylabel("city miles per gallon")
plt.show()
#there is a positive relation

# %% [markdown]
# ### 5. Show distributions and scatters between all variables by type of drive train
# *  Which variables have the highest correlation? Guess it visually.
# *  Which variables have the lowest correlation? Guess it visually.

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(cars,palette='rainbow')

# %%
#highway miles per gallon and city miles per gallon have the strongest correlation while cycle and year have the lowest

# %% [markdown]
# ### 6. Which class has most observed in dataset.
# * Use countplot

# %%
sns.countplot(x='class',data=cars)
#suv is the most obesrved(>60)

# %% [markdown]
# ### 7. Visualize engine displacement by each class boxplot
# * Use boxplot

# %%
sns.boxplot(x="displ", y="class", data=cars,palette='dark')

# %% [markdown]
# ### 8. Do the same thing in violinplot

# %%
sns.violinplot(x="displ", y="class", data=cars,palette='dark')
